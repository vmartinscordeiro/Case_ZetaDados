# %%
import pandas as pd 

df_customers = pd.read_csv(r"C:\Users\vmart\OneDrive\Documentos\Case_ZetaDados\Archives\ingest_date=2025-12-01\customers.csv")
df_order_items = pd.read_csv(r"C:\Users\vmart\OneDrive\Documentos\Case_ZetaDados\Archives\ingest_date=2025-12-01\order_items.csv")
df_orders = pd.read_csv(r"C:\Users\vmart\OneDrive\Documentos\Case_ZetaDados\Archives\ingest_date=2025-12-01\orders.csv")
df_products = pd.read_csv(r"C:\Users\vmart\OneDrive\Documentos\Case_ZetaDados\Archives\ingest_date=2025-12-01\products.csv")
df_shipments = pd.read_csv(r"C:\Users\vmart\OneDrive\Documentos\Case_ZetaDados\Archives\ingest_date=2025-12-01\shipments.csv")

df_shipments.head(50)
# Out:
#    order_id        carrier shipping_cost           shipped_ts  \
# 0   O000001            NaN         39.57     02/12/2025 07:22
# 1   O000003      CORREIOS           0,00  2025-12-02 15:34:00
# 2   O000004  Total Express         34.36  2025-12-02 19:32:00
# 3   O000005            NaN         49.82  2025-12-01 04:26:00
# 4   O000006            NaN         56.35  2025-12-02 10:05:00
# 5   O000007      CORREIOS          54.04  2025-12-01 02:02:00
# 6   O000008            NaN         70.16  2025-12-01 20:46:00
# 7   O000009     Correios           38.95  2025-12-02 12:04:00
# 8   O000010      CORREIOS          26.67     02/12/2025 02:25
# 9   O000011            NaN         39.72                  NaN
# 10  O000013      CORREIOS          14.02     01/12/2025 10:00
# 11  O000014  Total Express         34.66  2025-12-02 02:17:00
# 12  O000015         Jadlog          4.96  2025-12-02 02:46:00
# 13  O000017            NaN         10.12     01/12/2025 08:49
# ...
